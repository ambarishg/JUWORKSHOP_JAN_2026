# %%
! pip install -r ../requirements.txt
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp312-cp312-win_amd64.whl size=155798 sha256=024abb0970836b6f3066a439749f8cb3567a7b4ec0a6f15ee4c42bdd4a98547f
#   Stored in directory: c:\users\ambarish ganguly\appdata\local\pip\cache\wheels\ac\39\b3\cbd7f9cbb76501d2d5fbc84956e70d0b94e788aac87bda465e
# Successfully built hnswlib
# ...
