# %%
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from config import *

# %%
project = AIProjectClient(
    endpoint=AZURE_OPENAI_ENDPOINT,
    credential=DefaultAzureCredential(),
)

# %%
models = project.get_openai_client(api_version="2024-10-21")
response = models.chat.completions.create(
    model=AZURE_OPENAI_DEPLOYMENT_ID,
    messages=[
        {"role": "system", "content": "You are a helpful writing assistant"},
        {"role": "user", "content": "Write me a poem about flowers"},
    ],
)

print(response.choices[0].message.content)
# Out:
# In a garden where the sunbeams play,
# Petals dance in a bright ballet,
# Crimson, violet, and golden hues,
# Whispers of beauty in morning’s dews.
#
# Daisies twirl in the gentle breeze,
# While lilacs sway among the trees,
# Their sweet perfume, a lingering song,
# Nature’s harmony, where hearts belong.
#
# Roses blush with a secret glow,
# Each thorn a tale the soft winds know,
# Tulips stand proud in their painted attire,
# A canvas of color, an artist's desire.
#
# Sunflowers stretch toward the azure sky,
# With faces turned where the day drifts by,
# They nod to the clouds, so airy and white,
# Basking in the warmth of the golden light.
#
# In every bloom, a story told,
# Of life and love, of brave and bold,
# A fleeting moment, yet eternal grace,
# Flowers remind us of our place.
#
# So gather the petals, the joy they bring,
# In each soft whisper, let your heart sing,
# For in this garden, where beauty bends,
# The language of flowers, a message transcends.
