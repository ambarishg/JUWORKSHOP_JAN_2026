# %%
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from config import *

# %%
project = AIProjectClient(
    endpoint=AZURE_OPENAI_ENDPOINT,
    credential=DefaultAzureCredential(),
)

# %%
models = project.get_openai_client(api_version="2024-10-21")
response = models.chat.completions.create(
    model=AZURE_OPENAI_DEPLOYMENT_ID,
    messages=[
        {"role": "system", "content": "You are a helpful writing assistant"},
        {"role": "user", "content": "Write me a poem about flowers"},
    ],
)

print(response.choices[0].message.content)
# Out:
# In gardens lush where colors weave,
# The gentle dance of petals breathe,
# A tapestry of vibrant hue,
# Each blossom crafted, fresh and new.
#
# Roses blush with deepest red,
# Whispering tales of love unsaid.
# Sunflowers turn to chase the sun,
# Their golden crowns a radiant run.
#
# Bluebells sing in the morning light,
# A symphony of delicate sight.
# Lilies pure, in quiet grace,
# Hold the dawn in their embrace.
#
# Daisies dot the emerald ground,
# In simple joy their beauty's found.
# Tulips stand in stately rows,
# With secrets that the springtime knows.
#
# Forget-me-nots, softly declare
# In hidden corners, "We're always there."
# A bloom for every heart that sings,
# In the gentle breath of Maytime springs.
#
# In flowers' language, silent yet bold,
# Their stories of the earth unfold.
# In transient beauty, fleeting yet dear,
# They mark the passage of each year.
#
# So let us wander through these fields,
# And cherish the gifts that nature yields.
# For in each petal and fragrant bower,
# Lies the eternal wonder of the flower.
